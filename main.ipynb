# %% [markdown]
# ## Define class for logs

# %%
import dataclasses
import datetime, time

@dataclasses.dataclass
class Logs:
    priority: int = None
    protocol_ver: int = 1
    timestamp: [datetime.datetime|float] = None
    host_name: str = None
    app_name: str = None
    process_id: int = None
    message_id: str = None
    struct_data: dict = dataclasses.field(default_factory=dict)
    message: str = None

    raw: str = None
    creation_time: float = None
    error: bool = False

    def __str__(self):
        if self.struct_data:
            struct_data = '[' + ' '.join([f'{key}="{value}"' for key, value in self.struct_data.items()]) + ']'
        else:
            struct_data = '-'

        # transform each None value to '-'
        for key, value in self.__dict__.items():
            if value is None:
                self.__dict__[key] = '-'

        return f'<{self.priority}>{self.protocol_ver} {self.timestamp:%Y-%m-%dT%H:%M:%S.%f+%z} {self.host_name} {self.app_name} {self.process_id} {self.message_id} {struct_data} {self.message}'

# %% [markdown]
# ### UNIX Logs

# %%
class UnixLogs(Logs):
    def __init__(self, raw):
        attributes = re.match(f'^(?P<timestamp>{MONTH} {DATE} {TIME}) (?P<host_name>\S+) (?:(?P<app_name>\S+)(?:\[(?P<process_id>\d+)\]): )?(?P<message>.*)$', raw).groupdict()
        # parse time
        attributes['timestamp'] = datetime.datetime.strptime(attributes['timestamp'], '%b %d %H:%M:%S').replace(year=datetime.datetime.now().year)
        super().__init__(**attributes, raw=raw)

# %% [markdown]
# ## Log rules

# %%
import re

MONTH = '(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)'
DAY = '(Mon|Tue|Wed|Thu|Fri|Sat|Sun)'
DATE = '([0 ][1-9]|[12][0-9]|3[01])'
TIME = '([01][0-9]|2[0-3]):[0-5][0-9]:[0-5][0-9]'

rules = {
    'boot.log(\.\d+)?': UnixLogs,
}

# %% [markdown]
# ## Read logs

# %%
def read_logs(log_file: str) -> list[str]:
    with open(log_file, 'r', encoding='utf8') as f:
        return [line for line in f]

def parse_logs(logs: list[str], parser_class: type) -> list[Logs]:
    parsed_logs = []
    for log in logs:
        try:
            parsed_logs.append(parser_class(log))
        except AttributeError:
            print('AttributeError', log)
            continue
    return parsed_logs

# %% [markdown]
# ## Walk logs

# %%
import os, os.path, pathlib

LOG_DIR = 'var'

errors = []
valid = []

i=0
for root, dirs, files in os.walk(LOG_DIR):
    for file in files:
        if i == 100:
            break
        print(os.path.join(root, file))
        try:
            logs = read_logs(os.path.join(root, file))
        except UnicodeDecodeError:
            print('UnicodeDecodeError', os.path.join(root, file))
            continue

        for key in rules:
            if re.match(key, file):
                logs = parse_logs(logs, UnixLogs)
                break
        else:
            continue

        print(*logs, sep='\n')
        i+=1

with open('errors.txt', 'w') as f:
    for error in errors:
        f.write(f'{error}\n')

# with open('valid.txt', 'w') as f:
#     for log in valid:
#         f.write(f'{log}\n')
# Out:
# var\log\boot.log
# <->1 2023-01-26T11:53:05.000000+ combo - - - - sendmail: sendmail shutdown failed
# <->1 2023-01-26T11:53:06.000000+ combo - - - - sendmail: sm-client shutdown failed
# <->1 2023-01-26T12:20:03.000000+ combo - - - - messagebus: messagebus -TERM succeeded
# <->1 2023-01-26T12:20:05.000000+ combo - - - - atd: atd shutdown succeeded
# <->1 2023-01-26T12:20:06.000000+ combo - - - - privoxy: privoxy shutdown succeeded
# <->1 2023-01-26T12:20:06.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-01-26T12:20:07.000000+ combo - - - - xfs: xfs shutdown succeeded
# <->1 2023-01-26T12:20:08.000000+ combo - - - - FreeWnn: jserver shutdown succeeded
# <->1 2023-01-26T12:20:08.000000+ combo - - - - canna: Stopping Canna server: succeeded
# <->1 2023-01-26T12:20:09.000000+ combo - - - - mysqld: Stopping MySQL:  failed
# <->1 2023-01-26T12:20:09.000000+ combo - - - - gpm: gpm shutdown succeeded
# <->1 2023-01-26T12:20:14.000000+ combo - - - - httpd: httpd shutdown succeeded
# <->1 2023-01-26T12:20:15.000000+ combo - - - - squid: Stopping squid:
# <->1 2023-01-26T12:20:17.000000+ combo - - - - squid: .
# <->1 2023-01-26T12:20:17.000000+ combo - - - - squid:
# <->1 2023-01-26T12:20:17.000000+ combo - - - - rc: Stopping squid:  succeeded
# <->1 2023-01-26T12:20:17.000000+ combo - - - - sshd: sshd -TERM succeeded
# <->1 2023-01-26T12:20:17.000000+ combo - - - - sendmail: sendmail shutdown failed
# <->1 2023-01-26T12:20:22.000000+ combo - - - - spamassassin: spamd shutdown succeeded
# <->1 2023-01-26T12:20:22.000000+ combo - - - - smartd: smartd shutdown succeeded
# <->1 2023-01-26T12:20:22.000000+ combo - - - - named: named shutdown failed
# <->1 2023-01-26T12:20:27.000000+ combo - - - - snmpd: snmpd shutdown succeeded
# <->1 2023-01-26T12:20:28.000000+ combo - - - - xinetd: xinetd shutdown succeeded
# <->1 2023-01-26T12:20:28.000000+ combo - - - - crond: crond shutdown succeeded
# <->1 2023-01-26T12:20:29.000000+ combo - - - - apmd: apmd shutdown succeeded
# <->1 2023-01-26T12:20:30.000000+ combo - - - - ntpd: ntpd shutdown succeeded
# <->1 2023-01-26T12:20:30.000000+ combo - - - - dd: 1+0 records in
# <->1 2023-01-26T12:20:30.000000+ combo - - - - dd: 1+0 records out
# <->1 2023-01-26T12:20:30.000000+ combo - - - - random: Saving random seed:  succeeded
# <->1 2023-01-26T12:20:30.000000+ combo - - - - nfslock: rpc.statd shutdown succeeded
# <->1 2023-01-26T12:20:31.000000+ combo - - - - portmap: portmap shutdown succeeded
# <->1 2023-01-26T12:20:32.000000+ combo - - - - syslog: klogd shutdown succeeded
# <->1 2023-01-26T12:22:06.000000+ combo - - - - syslog: syslogd startup succeeded
# <->1 2023-01-26T12:22:06.000000+ combo - - - - syslog: klogd startup succeeded
# <->1 2023-01-26T12:22:06.000000+ combo - - - - irqbalance: irqbalance startup succeeded
# <->1 2023-01-26T12:22:07.000000+ combo - - - - portmap: portmap startup succeeded
# <->1 2023-01-26T12:22:07.000000+ combo - - - - nfslock: rpc.statd startup succeeded
# <->1 2023-01-26T12:22:08.000000+ combo - - - - rpcidmapd: rpc.idmapd startup succeeded
# <->1 2023-01-26T12:22:03.000000+ combo - - - - network: Setting network parameters:  succeeded
# <->1 2023-01-26T12:22:08.000000+ combo - - - - random: Initializing random number generator:  succeeded
# <->1 2023-01-26T12:22:03.000000+ combo - - - - network: Bringing up loopback interface:  succeeded
# <->1 2023-01-26T12:22:08.000000+ combo - - - - rc: Starting pcmcia:  succeeded
# <->1 2023-01-26T12:22:08.000000+ combo - - - - bluetooth: hcid startup succeeded
# <->1 2023-01-26T12:22:09.000000+ combo - - - - bluetooth: sdpd startup succeeded
# <->1 2023-01-26T12:22:09.000000+ combo - - - - netfs: Mounting other filesystems:  succeeded
# <->1 2023-01-26T12:22:09.000000+ combo - - - - apmd: apmd startup succeeded
# <->1 2023-01-26T12:22:10.000000+ combo - - - - autofs: automount startup succeeded
# <->1 2023-01-26T12:22:10.000000+ combo - - - - smartd: smartd startup succeeded
# <->1 2023-01-26T12:22:13.000000+ combo - - - - rc: Starting hpoj:  succeeded
# <->1 2023-01-26T12:22:27.000000+ combo - - - - cups: cupsd startup succeeded
# <->1 2023-01-26T12:22:28.000000+ combo - - - - sshd:  succeeded
# <->1 2023-01-26T12:22:28.000000+ combo - - - - xinetd: xinetd startup succeeded
# <->1 2023-01-26T12:22:30.000000+ combo - - - - sendmail: sendmail startup succeeded
# <->1 2023-01-26T12:22:30.000000+ combo - - - - sendmail: sm-client startup succeeded
# <->1 2023-01-26T12:22:42.000000+ combo - - - - spamassassin: spamd startup succeeded
# <->1 2023-01-26T12:22:42.000000+ combo - - - - privoxy: Jan 26 12:22:42 Privoxy(-150327168) Info: loading configuration file '/etc/privoxy/config':
# <->1 2023-01-26T12:22:43.000000+ combo - - - - privoxy: privoxy startup succeeded
# <->1 2023-01-26T12:22:44.000000+ combo - - - - gpm: gpm startup succeeded
# <->1 2023-01-26T12:22:45.000000+ combo - - - - IIim: htt startup succeeded
# <->1 2023-01-26T12:22:48.000000+ combo - - - - canna:  succeeded
# <->1 2023-01-26T12:22:48.000000+ combo - - - - crond: crond startup succeeded
# <->1 2023-01-26T12:22:50.000000+ combo - - - - xfs: xfs startup succeeded
# <->1 2023-01-26T12:22:50.000000+ combo - - - - anacron: anacron startup succeeded
# <->1 2023-01-26T12:22:51.000000+ combo - - - - atd: atd startup succeeded
# <->1 2023-01-26T12:22:51.000000+ combo - - - - readahead: Starting background readahead:
# <->1 2023-01-26T12:22:51.000000+ combo - - - - rc: Starting readahead:  succeeded
# <->1 2023-01-26T12:22:52.000000+ combo - - - - messagebus: messagebus startup succeeded
# <->1 2023-01-26T12:23:07.000000+ combo - - - - httpd: httpd startup succeeded
# <->1 2023-01-26T12:23:17.000000+ combo - - - - named: named startup succeeded
# <->1 2023-01-26T12:23:20.000000+ combo - - - - snmpd: snmpd startup succeeded
# <->1 2023-01-26T12:23:22.000000+ combo - - - - ntpd: ntpd startup succeeded
# <->1 2023-01-26T12:23:28.000000+ combo - - - - mysqld: Starting MySQL:  succeeded
# <->1 2023-01-26T12:23:30.000000+ combo - - - - mdmonitor: mdadm succeeded
# <->1 2023-01-26T12:23:31.000000+ combo - - - - mdmpd: mdmpd failed
# <->1 2023-01-26T12:55:20.000000+ combo - - - - sendmail: sendmail shutdown succeeded
# <->1 2023-01-26T12:55:20.000000+ combo - - - - sendmail: sm-client shutdown succeeded
# var\log\boot.log.1
# <->1 2023-01-22T04:10:50.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-01-22T04:10:55.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.10
# <->1 2023-11-20T04:08:59.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-11-20T04:09:08.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.11
# <->1 2023-11-13T04:12:43.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-11-13T04:13:09.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.12
# <->1 2023-11-06T04:05:54.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-11-06T04:06:00.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.13
# <->1 2023-10-25T10:06:09.000000+ combo - - - - messagebus: messagebus -TERM succeeded
# <->1 2023-10-25T10:06:11.000000+ combo - - - - atd: atd shutdown succeeded
# <->1 2023-10-25T10:06:12.000000+ combo - - - - privoxy: privoxy shutdown succeeded
# <->1 2023-10-25T10:06:12.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-10-25T10:06:14.000000+ combo - - - - xfs: xfs shutdown succeeded
# <->1 2023-10-25T10:06:14.000000+ combo - - - - FreeWnn: jserver shutdown succeeded
# <->1 2023-10-25T10:06:14.000000+ combo - - - - canna: Stopping Canna server: succeeded
# <->1 2023-10-25T10:06:15.000000+ combo - - - - mysqld: Stopping MySQL:  succeeded
# <->1 2023-10-25T10:06:16.000000+ combo - - - - gpm: gpm shutdown succeeded
# <->1 2023-10-25T10:06:21.000000+ combo - - - - httpd: httpd shutdown succeeded
# <->1 2023-10-25T10:06:22.000000+ combo - - - - squid: Stopping squid:
# <->1 2023-10-25T10:06:24.000000+ combo - - - - squid: .
# <->1 2023-10-25T10:06:54.000000+ combo - - - - last message repeated 15 times
# <->1 2023-10-25T10:06:54.000000+ combo - - - - squid: ^[[60G[  ^[
# <->1 2023-10-25T10:06:54.000000+ combo - - - - squid:
# <->1 2023-10-25T10:06:54.000000+ combo - - - - rc: Stopping squid:  succeeded
# <->1 2023-10-25T10:06:54.000000+ combo - - - - sshd: sshd -TERM succeeded
# <->1 2023-10-25T10:06:55.000000+ combo - - - - sendmail: sendmail shutdown succeeded
# <->1 2023-10-25T10:06:55.000000+ combo - - - - sendmail: sm-client shutdown succeeded
# <->1 2023-10-25T10:06:59.000000+ combo - - - - spamassassin: spamd shutdown succeeded
# <->1 2023-10-25T10:07:00.000000+ combo - - - - smartd: smartd shutdown succeeded
# <->1 2023-10-25T10:07:05.000000+ combo - - - - named: named shutdown succeeded
# <->1 2023-10-25T10:07:06.000000+ combo - - - - snmpd: snmpd shutdown succeeded
# <->1 2023-10-25T10:07:07.000000+ combo - - - - xinetd: xinetd shutdown succeeded
# <->1 2023-10-25T10:07:08.000000+ combo - - - - crond: crond shutdown succeeded
# <->1 2023-10-25T10:07:09.000000+ combo - - - - apmd: apmd shutdown succeeded
# <->1 2023-10-25T10:07:09.000000+ combo - - - - ntpd: ntpd shutdown succeeded
# <->1 2023-10-25T10:07:09.000000+ combo - - - - dd: 1+0 records in
# <->1 2023-10-25T10:07:09.000000+ combo - - - - dd: 1+0 records out
# <->1 2023-10-25T10:07:09.000000+ combo - - - - random: Saving random seed:  succeeded
# <->1 2023-10-25T10:07:11.000000+ combo - - - - nfslock: rpc.statd shutdown succeeded
# <->1 2023-10-25T10:07:11.000000+ combo - - - - portmap: portmap shutdown succeeded
# <->1 2023-10-25T10:08:46.000000+ combo - - - - syslog: syslogd startup succeeded
# <->1 2023-10-25T10:08:46.000000+ combo - - - - syslog: klogd startup succeeded
# <->1 2023-10-25T10:08:46.000000+ combo - - - - irqbalance: irqbalance startup succeeded
# <->1 2023-10-25T10:08:47.000000+ combo - - - - portmap: portmap startup succeeded
# <->1 2023-10-25T10:08:47.000000+ combo - - - - nfslock: rpc.statd startup succeeded
# <->1 2023-10-25T10:08:48.000000+ combo - - - - rpcidmapd: rpc.idmapd startup succeeded
# <->1 2023-10-25T10:08:48.000000+ combo - - - - random: Initializing random number generator:  succeeded
# <->1 2023-10-25T10:08:48.000000+ combo - - - - rc: Starting pcmcia:  succeeded
# <->1 2023-10-25T10:08:43.000000+ combo - - - - sysctl: net.ipv4.conf.default.rp_filter = 1
# <->1 2023-10-25T10:08:43.000000+ combo - - - - sysctl: kernel.sysrq = 0
# <->1 2023-10-25T10:08:48.000000+ combo - - - - bluetooth: hcid startup succeeded
# <->1 2023-10-25T10:08:43.000000+ combo - - - - sysctl: kernel.core_uses_pid = 1
# <->1 2023-10-25T10:08:49.000000+ combo - - - - bluetooth: sdpd startup succeeded
# <->1 2023-10-25T10:08:43.000000+ combo - - - - network: Setting network parameters:  succeeded
# <->1 2023-10-25T10:08:43.000000+ combo - - - - network: Bringing up loopback interface:  succeeded
# <->1 2023-10-25T10:08:49.000000+ combo - - - - netfs: Mounting other filesystems:  succeeded
# <->1 2023-10-25T10:08:49.000000+ combo - - - - apmd: apmd startup succeeded
# <->1 2023-10-25T10:08:50.000000+ combo - - - - autofs: automount startup succeeded
# <->1 2023-10-25T10:08:50.000000+ combo - - - - smartd: smartd startup succeeded
# <->1 2023-10-25T10:08:52.000000+ combo - - - - rc: Starting hpoj:  succeeded
# <->1 2023-10-25T10:09:06.000000+ combo - - - - cups: cupsd startup succeeded
# <->1 2023-10-25T10:09:06.000000+ combo - - - - sshd:  succeeded
# <->1 2023-10-25T10:09:06.000000+ combo - - - - xinetd: xinetd startup succeeded
# <->1 2023-10-25T10:09:09.000000+ combo - - - - sendmail: sendmail startup succeeded
# <->1 2023-10-25T10:09:10.000000+ combo - - - - sendmail: sm-client startup succeeded
# <->1 2023-10-25T10:09:16.000000+ combo - - - - spamassassin: spamd startup succeeded
# <->1 2023-10-25T10:09:16.000000+ combo - - - - privoxy: Oct 25 10:09:16 Privoxy(-150089600) Info: loading configuration file '/etc/privoxy/config':
# <->1 2023-10-25T10:09:17.000000+ combo - - - - privoxy: privoxy startup succeeded
# <->1 2023-10-25T10:09:18.000000+ combo - - - - gpm: gpm startup succeeded
# <->1 2023-10-25T10:09:18.000000+ combo - - - - IIim: htt startup succeeded
# <->1 2023-10-25T10:09:21.000000+ combo - - - - canna:  succeeded
# <->1 2023-10-25T10:09:21.000000+ combo - - - - crond: crond startup succeeded
# <->1 2023-10-25T10:09:22.000000+ combo - - - - xfs: xfs startup succeeded
# <->1 2023-10-25T10:09:22.000000+ combo - - - - anacron: anacron startup succeeded
# <->1 2023-10-25T10:09:22.000000+ combo - - - - atd: atd startup succeeded
# <->1 2023-10-25T10:09:22.000000+ combo - - - - readahead: Starting background readahead:
# <->1 2023-10-25T10:09:23.000000+ combo - - - - rc: Starting readahead:  succeeded
# <->1 2023-10-25T10:09:24.000000+ combo - - - - messagebus: messagebus startup succeeded
# <->1 2023-10-25T10:09:37.000000+ combo - - - - httpd: httpd startup succeeded
# <->1 2023-10-25T10:09:47.000000+ combo - - - - named: named startup succeeded
# <->1 2023-10-25T10:09:49.000000+ combo - - - - snmpd: snmpd startup succeeded
# <->1 2023-10-25T10:09:51.000000+ combo - - - - ntpd: ntpd startup succeeded
# <->1 2023-10-25T10:09:57.000000+ combo - - - - mysqld: Starting MySQL:  succeeded
# <->1 2023-10-25T10:09:58.000000+ combo - - - - mdmonitor: mdadm succeeded
# <->1 2023-10-25T10:09:58.000000+ combo - - - - mdmpd: mdmpd failed
# <->1 2023-10-30T04:04:30.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-10-30T04:04:35.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.14
# <->1 2023-10-23T04:03:34.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-10-23T04:03:40.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.15
# <->1 2023-10-16T04:09:10.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-10-16T04:09:31.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.16
# <->1 2023-10-09T04:08:16.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-10-09T04:08:43.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.17
# <->1 2023-09-28T09:03:45.000000+ combo - - - - sendmail: sendmail shutdown failed
# <->1 2023-09-28T09:03:55.000000+ combo - - - - sendmail: sm-client shutdown succeeded
# <->1 2023-09-28T09:08:35.000000+ combo - - - - messagebus: messagebus -TERM succeeded
# <->1 2023-09-28T09:08:36.000000+ combo - - - - atd: atd shutdown succeeded
# <->1 2023-09-28T09:08:38.000000+ combo - - - - privoxy: privoxy shutdown succeeded
# <->1 2023-09-28T09:08:39.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-09-28T09:08:40.000000+ combo - - - - xfs: xfs shutdown succeeded
# <->1 2023-09-28T09:08:41.000000+ combo - - - - FreeWnn: jserver shutdown succeeded
# <->1 2023-09-28T09:08:42.000000+ combo - - - - canna: Stopping Canna server: succeeded
# <->1 2023-09-28T09:08:42.000000+ combo - - - - mysqld: Stopping MySQL:  succeeded
# <->1 2023-09-28T09:08:44.000000+ combo - - - - gpm: gpm shutdown succeeded
# <->1 2023-09-28T09:08:48.000000+ combo - - - - httpd: httpd shutdown succeeded
# <->1 2023-09-28T09:08:49.000000+ combo - - - - squid: Stopping squid:
# <->1 2023-09-28T09:08:52.000000+ combo - - - - squid: .
# <->1 2023-09-28T09:08:56.000000+ combo - - - - last message repeated 2 times
# <->1 2023-09-28T09:08:56.000000+ combo - - - - squid:
# <->1 2023-09-28T09:08:57.000000+ combo - - - - rc: Stopping squid:  succeeded
# <->1 2023-09-28T09:08:57.000000+ combo - - - - sshd: sshd -TERM succeeded
# <->1 2023-09-28T09:08:58.000000+ combo - - - - sendmail: sendmail shutdown failed
# <->1 2023-09-28T09:09:03.000000+ combo - - - - spamassassin: spamd shutdown succeeded
# <->1 2023-09-28T09:09:04.000000+ combo - - - - smartd: smartd shutdown succeeded
# <->1 2023-09-28T09:09:08.000000+ combo - - - - named: named shutdown succeeded
# <->1 2023-09-28T09:09:12.000000+ combo - - - - snmpd: snmpd shutdown succeeded
# <->1 2023-09-28T09:09:14.000000+ combo - - - - xinetd: xinetd shutdown succeeded
# <->1 2023-09-28T09:09:14.000000+ combo - - - - crond: crond shutdown succeeded
# <->1 2023-09-28T09:09:15.000000+ combo - - - - apmd: apmd shutdown succeeded
# <->1 2023-09-28T09:09:15.000000+ combo - - - - ntpd: ntpd shutdown succeeded
# <->1 2023-09-28T09:09:15.000000+ combo - - - - dd: 1+0 records in
# <->1 2023-09-28T09:09:15.000000+ combo - - - - dd: 1+0 records out
# <->1 2023-09-28T09:09:16.000000+ combo - - - - random: Saving random seed:  succeeded
# <->1 2023-09-28T09:09:17.000000+ combo - - - - nfslock: rpc.statd shutdown succeeded
# <->1 2023-09-28T09:09:17.000000+ combo - - - - portmap: portmap shutdown succeeded
# <->1 2023-09-28T09:10:48.000000+ combo - - - - syslog: syslogd startup succeeded
# <->1 2023-09-28T09:10:48.000000+ combo - - - - syslog: klogd startup succeeded
# <->1 2023-09-28T09:10:49.000000+ combo - - - - irqbalance: irqbalance startup succeeded
# <->1 2023-09-28T09:10:49.000000+ combo - - - - portmap: portmap startup succeeded
# <->1 2023-09-28T09:10:49.000000+ combo - - - - nfslock: rpc.statd startup succeeded
# <->1 2023-09-28T09:10:50.000000+ combo - - - - rpcidmapd: rpc.idmapd startup succeeded
# <->1 2023-09-28T09:10:50.000000+ combo - - - - random: Initializing random number generator:  succeeded
# <->1 2023-09-28T09:10:50.000000+ combo - - - - rc: Starting pcmcia:  succeeded
# <->1 2023-09-28T09:10:50.000000+ combo - - - - bluetooth: hcid startup succeeded
# <->1 2023-09-28T09:10:48.000000+ combo - - - - network: Bringing up interface eth0:  succeeded
# <->1 2023-09-28T09:10:51.000000+ combo - - - - bluetooth: sdpd startup succeeded
# <->1 2023-09-28T09:10:51.000000+ combo - - - - netfs: Mounting other filesystems:  succeeded
# <->1 2023-09-28T09:10:51.000000+ combo - - - - apmd: apmd startup succeeded
# <->1 2023-09-28T09:10:52.000000+ combo - - - - autofs: automount startup succeeded
# <->1 2023-09-28T09:10:53.000000+ combo - - - - smartd: smartd startup succeeded
# <->1 2023-09-28T09:10:55.000000+ combo - - - - rc: Starting hpoj:  succeeded
# <->1 2023-09-28T09:11:06.000000+ combo - - - - cups: cupsd startup succeeded
# <->1 2023-09-28T09:11:06.000000+ combo - - - - sshd:  succeeded
# <->1 2023-09-28T09:11:06.000000+ combo - - - - xinetd: xinetd startup succeeded
# <->1 2023-09-28T09:11:09.000000+ combo - - - - sendmail: sendmail startup succeeded
# <->1 2023-09-28T09:11:09.000000+ combo - - - - sendmail: sm-client startup succeeded
# <->1 2023-09-28T09:11:18.000000+ combo - - - - spamassassin: spamd startup succeeded
# <->1 2023-09-28T09:11:18.000000+ combo - - - - privoxy: Sep 28 09:11:18 Privoxy(-150880128) Info: loading configuration file '/etc/privoxy/config':
# <->1 2023-09-28T09:11:19.000000+ combo - - - - privoxy: privoxy startup succeeded
# <->1 2023-09-28T09:11:20.000000+ combo - - - - gpm: gpm startup succeeded
# <->1 2023-09-28T09:11:21.000000+ combo - - - - IIim: htt startup succeeded
# <->1 2023-09-28T09:11:25.000000+ combo - - - - canna:  succeeded
# <->1 2023-09-28T09:11:25.000000+ combo - - - - crond: crond startup succeeded
# <->1 2023-09-28T09:11:30.000000+ combo - - - - xfs: xfs startup succeeded
# <->1 2023-09-28T09:11:30.000000+ combo - - - - anacron: anacron startup succeeded
# <->1 2023-09-28T09:11:30.000000+ combo - - - - atd: atd startup succeeded
# <->1 2023-09-28T09:11:31.000000+ combo - - - - readahead: Starting background readahead:
# <->1 2023-09-28T09:11:31.000000+ combo - - - - rc: Starting readahead:  succeeded
# <->1 2023-09-28T09:11:32.000000+ combo - - - - messagebus: messagebus startup succeeded
# <->1 2023-09-28T09:11:52.000000+ combo - - - - httpd: httpd startup succeeded
# <->1 2023-09-28T09:12:04.000000+ combo - - - - named: named startup succeeded
# <->1 2023-09-28T09:12:07.000000+ combo - - - - snmpd: snmpd startup succeeded
# <->1 2023-09-28T09:12:10.000000+ combo - - - - ntpd: ntpd startup succeeded
# <->1 2023-09-28T09:12:20.000000+ combo - - - - mysqld: Starting MySQL:  succeeded
# <->1 2023-09-28T09:12:22.000000+ combo - - - - mdmonitor: mdadm succeeded
# <->1 2023-09-28T09:12:22.000000+ combo - - - - mdmpd: mdmpd failed
# <->1 2023-09-29T12:28:40.000000+ combo - - - - sendmail: sendmail shutdown failed
# <->1 2023-09-29T12:28:40.000000+ combo - - - - sendmail: sm-client shutdown failed
# <->1 2023-09-29T12:32:04.000000+ combo - - - - sendmail: sendmail startup succeeded
# <->1 2023-09-29T12:32:04.000000+ combo - - - - sendmail: sm-client startup succeeded
# <->1 2023-10-02T04:06:29.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-10-02T04:06:35.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.18
# <->1 2023-09-19T05:57:37.000000+ combo - - - - syslog: syslogd startup succeeded
# <->1 2023-09-19T05:57:37.000000+ combo - - - - syslog: klogd startup succeeded
# <->1 2023-09-19T05:57:37.000000+ combo - - - - irqbalance: irqbalance startup succeeded
# <->1 2023-09-19T05:57:37.000000+ combo - - - - portmap: portmap startup succeeded
# <->1 2023-09-19T05:57:37.000000+ combo - - - - nfslock: rpc.statd startup succeeded
# <->1 2023-09-19T05:57:38.000000+ combo - - - - rpcidmapd: rpc.idmapd startup succeeded
# <->1 2023-09-19T05:57:38.000000+ combo - - - - random: Initializing random number generator:  succeeded
# <->1 2023-09-19T05:57:38.000000+ combo - - - - rc: Starting pcmcia:  succeeded
# <->1 2023-09-19T05:57:34.000000+ combo - - - - network: Setting network parameters:  succeeded
# <->1 2023-09-19T05:57:39.000000+ combo - - - - bluetooth: hcid startup succeeded
# <->1 2023-09-19T05:57:34.000000+ combo - - - - network: Bringing up loopback interface:  succeeded
# <->1 2023-09-19T05:57:39.000000+ combo - - - - bluetooth: sdpd startup succeeded
# <->1 2023-09-19T05:57:39.000000+ combo - - - - netfs: Mounting other filesystems:  succeeded
# <->1 2023-09-19T05:57:40.000000+ combo - - - - apmd: apmd startup succeeded
# <->1 2023-09-19T05:57:40.000000+ combo - - - - autofs: automount startup succeeded
# <->1 2023-09-19T05:57:41.000000+ combo - - - - smartd: smartd startup succeeded
# <->1 2023-09-19T05:57:42.000000+ combo - - - - rc: Starting hpoj:  succeeded
# <->1 2023-09-19T05:57:53.000000+ combo - - - - cups: cupsd startup succeeded
# <->1 2023-09-19T05:57:53.000000+ combo - - - - sshd:  succeeded
# <->1 2023-09-19T05:57:53.000000+ combo - - - - xinetd: xinetd startup succeeded
# <->1 2023-09-19T05:57:54.000000+ combo - - - - sendmail: sendmail startup succeeded
# <->1 2023-09-19T05:57:54.000000+ combo - - - - sendmail: sm-client startup succeeded
# <->1 2023-09-19T05:57:57.000000+ combo - - - - spamassassin: spamd startup succeeded
# <->1 2023-09-19T05:57:58.000000+ combo - - - - privoxy: Sep 19 05:57:58 Privoxy(-150429568) Info: loading configuration file '/etc/privoxy/config':
# <->1 2023-09-19T05:57:59.000000+ combo - - - - privoxy: privoxy startup succeeded
# <->1 2023-09-19T05:58:00.000000+ combo - - - - gpm: gpm startup succeeded
# <->1 2023-09-19T05:58:00.000000+ combo - - - - IIim: htt startup succeeded
# <->1 2023-09-19T05:58:03.000000+ combo - - - - canna:  succeeded
# <->1 2023-09-19T05:58:03.000000+ combo - - - - crond: crond startup succeeded
# <->1 2023-09-19T05:58:05.000000+ combo - - - - xfs: xfs startup succeeded
# <->1 2023-09-19T05:58:05.000000+ combo - - - - anacron: anacron startup succeeded
# <->1 2023-09-19T05:58:05.000000+ combo - - - - atd: atd startup succeeded
# <->1 2023-09-19T05:58:05.000000+ combo - - - - readahead: Starting background readahead:
# <->1 2023-09-19T05:58:06.000000+ combo - - - - rc: Starting readahead:  succeeded
# <->1 2023-09-19T05:58:07.000000+ combo - - - - messagebus: messagebus startup succeeded
# <->1 2023-09-19T05:58:19.000000+ combo - - - - httpd: httpd startup succeeded
# <->1 2023-09-19T05:58:25.000000+ combo - - - - named: named startup succeeded
# <->1 2023-09-19T05:58:27.000000+ combo - - - - snmpd: snmpd startup succeeded
# <->1 2023-09-19T05:58:29.000000+ combo - - - - ntpd: ntpd startup succeeded
# <->1 2023-09-19T05:58:36.000000+ combo - - - - mysqld: Starting MySQL:  succeeded
# <->1 2023-09-19T05:58:38.000000+ combo - - - - mdmonitor: mdadm succeeded
# <->1 2023-09-19T05:58:38.000000+ combo - - - - mdmpd: mdmpd failed
# <->1 2023-09-25T04:11:08.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-09-25T04:11:14.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.19
# <->1 2023-09-18T04:07:05.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-09-18T04:07:11.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.2
# <->1 2023-01-15T04:11:13.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-01-15T04:11:19.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.20
# <->1 2023-09-11T04:03:41.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-09-11T04:03:46.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.21
# <->1 2023-09-04T04:03:58.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-09-04T04:04:04.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.22
# <->1 2023-08-28T04:10:26.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-08-28T04:10:32.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.23
# <->1 2023-08-21T04:03:37.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-08-21T04:03:42.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.24
# <->1 2023-08-14T04:03:39.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-08-14T04:03:44.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.25
# <->1 2023-08-02T07:46:28.000000+ combo - - - - mysqld: Stopping MySQL:  succeeded
# <->1 2023-08-02T07:46:32.000000+ combo - - - - mysqld: Starting MySQL:  succeeded
# <->1 2023-08-07T04:03:39.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-08-07T04:03:45.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.26
# <->1 2023-07-27T14:41:57.000000+ combo - - - - syslog: syslogd startup succeeded
# <->1 2023-07-27T14:41:57.000000+ combo - - - - syslog: klogd startup succeeded
# <->1 2023-07-27T14:41:57.000000+ combo - - - - irqbalance: irqbalance startup succeeded
# <->1 2023-07-27T14:41:57.000000+ combo - - - - portmap: portmap startup succeeded
# <->1 2023-07-27T14:41:58.000000+ combo - - - - nfslock: rpc.statd startup succeeded
# <->1 2023-07-27T14:41:58.000000+ combo - - - - rpcidmapd: rpc.idmapd startup succeeded
# <->1 2023-07-27T14:41:58.000000+ combo - - - - random: Initializing random number generator:  succeeded
# <->1 2023-07-27T14:41:58.000000+ combo - - - - rc: Starting pcmcia:  succeeded
# <->1 2023-07-27T14:41:54.000000+ combo - - - - sysctl: kernel.core_uses_pid = 1
# <->1 2023-07-27T14:41:59.000000+ combo - - - - bluetooth: hcid startup succeeded
# <->1 2023-07-27T14:41:54.000000+ combo - - - - network: Setting network parameters:  succeeded
# <->1 2023-07-27T14:41:59.000000+ combo - - - - bluetooth: sdpd startup succeeded
# <->1 2023-07-27T14:41:54.000000+ combo - - - - network: Bringing up loopback interface:  succeeded
# <->1 2023-07-27T14:42:00.000000+ combo - - - - netfs: Mounting other filesystems:  succeeded
# <->1 2023-07-27T14:42:00.000000+ combo - - - - apmd: apmd startup succeeded
# <->1 2023-07-27T14:42:00.000000+ combo - - - - autofs: automount startup succeeded
# <->1 2023-07-27T14:42:01.000000+ combo - - - - smartd: smartd startup succeeded
# <->1 2023-07-27T14:42:02.000000+ combo - - - - rc: Starting hpoj:  succeeded
# <->1 2023-07-27T14:42:13.000000+ combo - - - - cups: cupsd startup succeeded
# <->1 2023-07-27T14:42:13.000000+ combo - - - - sshd:  succeeded
# <->1 2023-07-27T14:42:13.000000+ combo - - - - xinetd: xinetd startup succeeded
# <->1 2023-07-27T14:42:15.000000+ combo - - - - sendmail: sendmail startup succeeded
# <->1 2023-07-27T14:42:15.000000+ combo - - - - sendmail: sm-client startup succeeded
# <->1 2023-07-27T14:42:18.000000+ combo - - - - spamassassin: spamd startup succeeded
# <->1 2023-07-27T14:42:19.000000+ combo - - - - privoxy: Jul 27 14:42:19 Privoxy(-150806400) Info: loading configuration file '/etc/privoxy/config':
# <->1 2023-07-27T14:42:20.000000+ combo - - - - privoxy: privoxy startup succeeded
# <->1 2023-07-27T14:42:20.000000+ combo - - - - gpm: gpm startup succeeded
# <->1 2023-07-27T14:42:21.000000+ combo - - - - IIim: htt startup succeeded
# <->1 2023-07-27T14:42:23.000000+ combo - - - - canna:  succeeded
# <->1 2023-07-27T14:42:23.000000+ combo - - - - crond: crond startup succeeded
# <->1 2023-07-27T14:42:25.000000+ combo - - - - xfs: xfs startup succeeded
# <->1 2023-07-27T14:42:25.000000+ combo - - - - anacron: anacron startup succeeded
# <->1 2023-07-27T14:42:25.000000+ combo - - - - atd: atd startup succeeded
# <->1 2023-07-27T14:42:25.000000+ combo - - - - readahead: Starting background readahead:
# <->1 2023-07-27T14:42:26.000000+ combo - - - - rc: Starting readahead:  succeeded
# <->1 2023-07-27T14:42:27.000000+ combo - - - - messagebus: messagebus startup succeeded
# <->1 2023-07-27T14:42:40.000000+ combo - - - - httpd: httpd startup succeeded
# <->1 2023-07-27T14:42:48.000000+ combo - - - - named: named startup succeeded
# <->1 2023-07-27T14:42:50.000000+ combo - - - - snmpd: snmpd startup succeeded
# <->1 2023-07-27T14:42:53.000000+ combo - - - - ntpd: ntpd startup succeeded
# <->1 2023-07-27T14:42:58.000000+ combo - - - - mysqld: Starting MySQL:  succeeded
# <->1 2023-07-27T14:42:59.000000+ combo - - - - mdmonitor: mdadm succeeded
# <->1 2023-07-27T14:43:00.000000+ combo - - - - mdmpd: mdmpd failed
# <->1 2023-07-31T04:08:42.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-07-31T04:08:48.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.27
# <->1 2023-07-24T04:20:21.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-07-24T04:20:26.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.28
# <->1 2023-07-17T04:08:10.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-07-17T04:08:16.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.29
# <->1 2023-07-10T04:04:33.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-07-10T04:04:39.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.3
# <->1 2023-01-08T04:05:46.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-01-08T04:05:51.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.30
# <->1 2023-07-03T04:07:49.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-07-03T04:07:55.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.31
# <->1 2023-06-26T04:04:19.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-06-26T04:04:24.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.32
# <->1 2023-06-19T04:08:57.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-06-19T04:09:02.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.33
# <->1 2023-06-09T06:06:20.000000+ combo - - - - syslog: syslogd startup succeeded
# <->1 2023-06-09T06:06:20.000000+ combo - - - - syslog: klogd startup succeeded
# <->1 2023-06-09T06:06:20.000000+ combo - - - - irqbalance: irqbalance startup succeeded
# <->1 2023-06-09T06:06:20.000000+ combo - - - - portmap: portmap startup succeeded
# <->1 2023-06-09T06:06:20.000000+ combo - - - - nfslock: rpc.statd startup succeeded
# <->1 2023-06-09T06:06:21.000000+ combo - - - - rpcidmapd: rpc.idmapd startup succeeded
# <->1 2023-06-09T06:06:21.000000+ combo - - - - random: Initializing random number generator:  succeeded
# <->1 2023-06-09T06:06:21.000000+ combo - - - - rc: Starting pcmcia:  succeeded
# <->1 2023-06-09T06:06:22.000000+ combo - - - - bluetooth: hcid startup succeeded
# <->1 2023-06-09T06:06:17.000000+ combo - - - - network: Setting network parameters:  succeeded
# <->1 2023-06-09T06:06:22.000000+ combo - - - - bluetooth: sdpd startup succeeded
# <->1 2023-06-09T06:06:17.000000+ combo - - - - network: Bringing up loopback interface:  succeeded
# <->1 2023-06-09T06:06:23.000000+ combo - - - - netfs: Mounting other filesystems:  succeeded
# <->1 2023-06-09T06:06:23.000000+ combo - - - - apmd: apmd startup succeeded
# <->1 2023-06-09T06:06:24.000000+ combo - - - - autofs: automount startup succeeded
# <->1 2023-06-09T06:06:24.000000+ combo - - - - smartd: smartd startup succeeded
# <->1 2023-06-09T06:06:26.000000+ combo - - - - rc: Starting hpoj:  succeeded
# <->1 2023-06-09T06:06:37.000000+ combo - - - - cups: cupsd startup succeeded
# <->1 2023-06-09T06:06:38.000000+ combo - - - - sshd:  succeeded
# <->1 2023-06-09T06:06:38.000000+ combo - - - - xinetd: xinetd startup succeeded
# <->1 2023-06-09T06:06:40.000000+ combo - - - - sendmail: sendmail startup succeeded
# <->1 2023-06-09T06:06:41.000000+ combo - - - - sendmail: sm-client startup succeeded
# <->1 2023-06-09T06:06:44.000000+ combo - - - - spamassassin: spamd startup succeeded
# <->1 2023-06-09T06:06:44.000000+ combo - - - - privoxy: Jun 09 06:06:44 Privoxy(-150093696) Info: loading configuration file '/etc/privoxy/config':
# <->1 2023-06-09T06:06:45.000000+ combo - - - - privoxy: privoxy startup succeeded
# <->1 2023-06-09T06:06:46.000000+ combo - - - - gpm: gpm startup succeeded
# <->1 2023-06-09T06:06:46.000000+ combo - - - - IIim: htt startup succeeded
# <->1 2023-06-09T06:06:49.000000+ combo - - - - canna:  succeeded
# <->1 2023-06-09T06:06:49.000000+ combo - - - - crond: crond startup succeeded
# <->1 2023-06-09T06:06:50.000000+ combo - - - - xfs: xfs startup succeeded
# <->1 2023-06-09T06:06:51.000000+ combo - - - - anacron: anacron startup succeeded
# <->1 2023-06-09T06:06:51.000000+ combo - - - - atd: atd startup succeeded
# <->1 2023-06-09T06:06:51.000000+ combo - - - - readahead: Starting background readahead:
# <->1 2023-06-09T06:06:51.000000+ combo - - - - rc: Starting readahead:  succeeded
# <->1 2023-06-09T06:06:52.000000+ combo - - - - messagebus: messagebus startup succeeded
# <->1 2023-06-09T06:07:06.000000+ combo - - - - httpd: httpd startup succeeded
# <->1 2023-06-09T06:07:13.000000+ combo - - - - named: named startup succeeded
# <->1 2023-06-09T06:07:15.000000+ combo - - - - snmpd: snmpd startup succeeded
# <->1 2023-06-09T06:07:17.000000+ combo - - - - ntpd: ntpd startup succeeded
# <->1 2023-06-09T06:07:22.000000+ combo - - - - mysqld: Starting MySQL:  succeeded
# <->1 2023-06-09T06:07:23.000000+ combo - - - - mdmonitor: mdadm succeeded
# <->1 2023-06-09T06:07:24.000000+ combo - - - - mdmpd: mdmpd failed
# <->1 2023-06-10T11:31:44.000000+ combo - - - - syslog: syslogd startup succeeded
# <->1 2023-06-10T11:31:44.000000+ combo - - - - syslog: klogd startup succeeded
# <->1 2023-06-10T11:31:44.000000+ combo - - - - irqbalance: irqbalance startup succeeded
# <->1 2023-06-10T11:31:44.000000+ combo - - - - portmap: portmap startup succeeded
# <->1 2023-06-10T11:31:44.000000+ combo - - - - nfslock: rpc.statd startup succeeded
# <->1 2023-06-10T11:31:45.000000+ combo - - - - rpcidmapd: rpc.idmapd startup succeeded
# <->1 2023-06-10T11:31:45.000000+ combo - - - - random: Initializing random number generator:  succeeded
# <->1 2023-06-10T11:31:45.000000+ combo - - - - rc: Starting pcmcia:  succeeded
# <->1 2023-06-10T11:31:41.000000+ combo - - - - sysctl: kernel.core_uses_pid = 1
# <->1 2023-06-10T11:31:46.000000+ combo - - - - bluetooth: hcid startup succeeded
# <->1 2023-06-10T11:31:41.000000+ combo - - - - network: Setting network parameters:  succeeded
# <->1 2023-06-10T11:31:46.000000+ combo - - - - bluetooth: sdpd startup succeeded
# <->1 2023-06-10T11:31:41.000000+ combo - - - - network: Bringing up loopback interface:  succeeded
# <->1 2023-06-10T11:31:46.000000+ combo - - - - netfs: Mounting other filesystems:  succeeded
# <->1 2023-06-10T11:31:47.000000+ combo - - - - apmd: apmd startup succeeded
# <->1 2023-06-10T11:31:47.000000+ combo - - - - autofs: automount startup succeeded
# <->1 2023-06-10T11:31:48.000000+ combo - - - - smartd: smartd startup succeeded
# <->1 2023-06-10T11:31:49.000000+ combo - - - - rc: Starting hpoj:  succeeded
# <->1 2023-06-10T11:32:00.000000+ combo - - - - cups: cupsd startup succeeded
# <->1 2023-06-10T11:32:00.000000+ combo - - - - sshd:  succeeded
# <->1 2023-06-10T11:32:00.000000+ combo - - - - xinetd: xinetd startup succeeded
# <->1 2023-06-10T11:32:01.000000+ combo - - - - sendmail: sendmail startup succeeded
# <->1 2023-06-10T11:32:01.000000+ combo - - - - sendmail: sm-client startup succeeded
# <->1 2023-06-10T11:32:05.000000+ combo - - - - spamassassin: spamd startup succeeded
# <->1 2023-06-10T11:32:05.000000+ combo - - - - privoxy: Jun 10 11:32:05 Privoxy(-150769536) Info: loading configuration file '/etc/privoxy/config':
# <->1 2023-06-10T11:32:06.000000+ combo - - - - privoxy: privoxy startup succeeded
# <->1 2023-06-10T11:32:07.000000+ combo - - - - gpm: gpm startup succeeded
# <->1 2023-06-10T11:32:07.000000+ combo - - - - IIim: htt startup succeeded
# <->1 2023-06-10T11:32:10.000000+ combo - - - - canna:  succeeded
# <->1 2023-06-10T11:32:10.000000+ combo - - - - crond: crond startup succeeded
# <->1 2023-06-10T11:32:12.000000+ combo - - - - xfs: xfs startup succeeded
# <->1 2023-06-10T11:32:12.000000+ combo - - - - anacron: anacron startup succeeded
# <->1 2023-06-10T11:32:12.000000+ combo - - - - atd: atd startup succeeded
# <->1 2023-06-10T11:32:12.000000+ combo - - - - readahead: Starting background readahead:
# <->1 2023-06-10T11:32:13.000000+ combo - - - - rc: Starting readahead:  succeeded
# <->1 2023-06-10T11:32:14.000000+ combo - - - - messagebus: messagebus startup succeeded
# <->1 2023-06-10T11:32:26.000000+ combo - - - - httpd: httpd startup succeeded
# <->1 2023-06-10T11:32:34.000000+ combo - - - - named: named startup succeeded
# <->1 2023-06-10T11:32:36.000000+ combo - - - - snmpd: snmpd startup succeeded
# <->1 2023-06-10T11:32:37.000000+ combo - - - - ntpd: ntpd startup succeeded
# <->1 2023-06-10T11:32:45.000000+ combo - - - - mysqld: Starting MySQL:  succeeded
# <->1 2023-06-10T11:32:47.000000+ combo - - - - mdmonitor: mdadm succeeded
# <->1 2023-06-10T11:32:47.000000+ combo - - - - mdmpd: mdmpd failed
# <->1 2023-06-12T04:04:09.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-06-12T04:04:15.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.4
# <->1 2023-01-01T04:02:07.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-01-01T04:02:13.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.5
# <->1 2023-12-25T04:02:07.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-12-25T04:02:13.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.6
# <->1 2023-12-18T04:02:08.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-12-18T04:02:14.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.7
# <->1 2023-12-06T12:20:20.000000+ combo - - - - messagebus: messagebus shutdown failed
# <->1 2023-12-06T12:20:23.000000+ combo - - - - atd: atd shutdown succeeded
# <->1 2023-12-06T12:20:24.000000+ combo - - - - privoxy: privoxy shutdown succeeded
# <->1 2023-12-06T12:20:28.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-12-06T12:20:29.000000+ combo - - - - xfs: xfs shutdown failed
# <->1 2023-12-06T12:20:29.000000+ combo - - - - FreeWnn: jserver shutdown failed
# <->1 2023-12-06T12:20:31.000000+ combo - - - - canna: Stopping Canna server: succeeded
# <->1 2023-12-06T12:20:31.000000+ combo - - - - mysqld: Stopping MySQL:  failed
# <->1 2023-12-06T12:20:33.000000+ combo - - - - gpm: gpm shutdown succeeded
# <->1 2023-12-06T12:20:37.000000+ combo - - - - httpd: httpd shutdown succeeded
# <->1 2023-12-06T12:20:39.000000+ combo - - - - squid: Stopping squid:
# <->1 2023-12-06T12:20:43.000000+ combo - - - - squid: .
# <->1 2023-12-06T12:20:45.000000+ combo - - - - squid: .
# <->1 2023-12-06T12:20:45.000000+ combo - - - - squid: ^[[60G[  ^[OK
# <->1 2023-12-06T12:20:45.000000+ combo - - - - squid:
# <->1 2023-12-06T12:20:45.000000+ combo - - - - rc: Stopping squid:  succeeded
# <->1 2023-12-06T12:20:45.000000+ combo - - - - sshd: sshd -TERM succeeded
# <->1 2023-12-06T12:20:50.000000+ combo - - - - sendmail: sendmail shutdown succeeded
# <->1 2023-12-06T12:20:50.000000+ combo - - - - sendmail: sm-client shutdown failed
# <->1 2023-12-06T12:21:01.000000+ combo - - - - spamassassin: spamd shutdown succeeded
# <->1 2023-12-06T12:21:03.000000+ combo - - - - smartd: smartd shutdown succeeded
# <->1 2023-12-06T12:21:10.000000+ combo - - - - named: named shutdown failed
# <->1 2023-12-06T12:21:14.000000+ combo - - - - snmpd: snmpd shutdown succeeded
# <->1 2023-12-06T12:21:16.000000+ combo - - - - xinetd: xinetd shutdown succeeded
# <->1 2023-12-06T12:21:16.000000+ combo - - - - crond: crond shutdown succeeded
# <->1 2023-12-06T12:21:20.000000+ combo - - - - apmd: apmd shutdown succeeded
# <->1 2023-12-06T12:21:21.000000+ combo - - - - ntpd: ntpd shutdown succeeded
# <->1 2023-12-06T12:21:21.000000+ combo - - - - dd: 1+0 records in
# <->1 2023-12-06T12:21:21.000000+ combo - - - - dd: 1+0 records out
# <->1 2023-12-06T12:21:21.000000+ combo - - - - random: Saving random seed:  succeeded
# <->1 2023-12-06T12:21:21.000000+ combo - - - - nfslock: rpc.statd shutdown failed
# <->1 2023-12-06T12:21:21.000000+ combo - - - - portmap: portmap shutdown failed
# <->1 2023-12-06T12:22:57.000000+ combo - - - - syslog: syslogd startup succeeded
# <->1 2023-12-06T12:22:57.000000+ combo - - - - syslog: klogd startup succeeded
# <->1 2023-12-06T12:22:57.000000+ combo - - - - irqbalance: irqbalance startup succeeded
# <->1 2023-12-06T12:22:57.000000+ combo - - - - portmap: portmap startup succeeded
# <->1 2023-12-06T12:22:58.000000+ combo - - - - nfslock: rpc.statd startup succeeded
# <->1 2023-12-06T12:22:59.000000+ combo - - - - rpcidmapd: rpc.idmapd startup succeeded
# <->1 2023-12-06T12:22:59.000000+ combo - - - - random: Initializing random number generator:  succeeded
# <->1 2023-12-06T12:22:54.000000+ combo - - - - sysctl: net.ipv4.conf.default.rp_filter = 1
# <->1 2023-12-06T12:22:54.000000+ combo - - - - sysctl: kernel.sysrq = 0
# <->1 2023-12-06T12:22:54.000000+ combo - - - - sysctl: kernel.core_uses_pid = 1
# <->1 2023-12-06T12:22:54.000000+ combo - - - - network: Setting network parameters:  succeeded
# <->1 2023-12-06T12:22:59.000000+ combo - - - - rc: Starting pcmcia:  succeeded
# <->1 2023-12-06T12:22:54.000000+ combo - - - - network: Bringing up loopback interface:  succeeded
# <->1 2023-12-06T12:22:59.000000+ combo - - - - bluetooth: hcid startup succeeded
# <->1 2023-12-06T12:23:00.000000+ combo - - - - bluetooth: sdpd startup succeeded
# <->1 2023-12-06T12:23:00.000000+ combo - - - - netfs: Mounting other filesystems:  succeeded
# <->1 2023-12-06T12:23:00.000000+ combo - - - - apmd: apmd startup succeeded
# <->1 2023-12-06T12:23:01.000000+ combo - - - - autofs: automount startup succeeded
# <->1 2023-12-06T12:23:01.000000+ combo - - - - smartd: smartd startup succeeded
# <->1 2023-12-06T12:23:03.000000+ combo - - - - rc: Starting hpoj:  succeeded
# <->1 2023-12-06T12:23:15.000000+ combo - - - - cups: cupsd startup succeeded
# <->1 2023-12-06T12:23:16.000000+ combo - - - - sshd:  succeeded
# <->1 2023-12-06T12:23:16.000000+ combo - - - - xinetd: xinetd startup succeeded
# <->1 2023-12-06T12:23:19.000000+ combo - - - - sendmail: sendmail startup succeeded
# <->1 2023-12-06T12:23:19.000000+ combo - - - - sendmail: sm-client startup succeeded
# <->1 2023-12-06T12:23:27.000000+ combo - - - - spamassassin: spamd startup succeeded
# <->1 2023-12-06T12:23:28.000000+ combo - - - - privoxy: Dec 06 12:23:28 Privoxy(-150085504) Info: loading configuration file '/etc/privoxy/config':
# <->1 2023-12-06T12:23:29.000000+ combo - - - - privoxy: privoxy startup succeeded
# <->1 2023-12-06T12:23:30.000000+ combo - - - - gpm: gpm startup succeeded
# <->1 2023-12-06T12:23:30.000000+ combo - - - - IIim: htt startup succeeded
# <->1 2023-12-06T12:23:35.000000+ combo - - - - canna:  succeeded
# <->1 2023-12-06T12:23:35.000000+ combo - - - - crond: crond startup succeeded
# <->1 2023-12-06T12:23:45.000000+ combo - - - - xfs: xfs startup succeeded
# <->1 2023-12-06T12:23:45.000000+ combo - - - - anacron: anacron startup succeeded
# <->1 2023-12-06T12:23:46.000000+ combo - - - - atd: atd startup succeeded
# <->1 2023-12-06T12:23:46.000000+ combo - - - - readahead: Starting background readahead:
# <->1 2023-12-06T12:23:46.000000+ combo - - - - rc: Starting readahead:  succeeded
# <->1 2023-12-06T12:23:47.000000+ combo - - - - messagebus: messagebus startup succeeded
# <->1 2023-12-06T12:24:08.000000+ combo - - - - httpd: httpd startup succeeded
# <->1 2023-12-06T12:24:19.000000+ combo - - - - named: named startup succeeded
# <->1 2023-12-06T12:24:22.000000+ combo - - - - snmpd: snmpd startup succeeded
# <->1 2023-12-06T12:24:23.000000+ combo - - - - ntpd: ntpd startup succeeded
# <->1 2023-12-06T12:24:32.000000+ combo - - - - mysqld: Starting MySQL:  succeeded
# <->1 2023-12-06T12:24:34.000000+ combo - - - - mdmonitor: mdadm succeeded
# <->1 2023-12-06T12:24:35.000000+ combo - - - - mdmpd: mdmpd failed
# <->1 2023-12-09T09:43:21.000000+ combo - - - - syslog: syslogd shutdown succeeded
# <->1 2023-12-09T09:43:25.000000+ combo - - - - syslog: syslogd startup succeeded
# <->1 2023-12-09T09:43:25.000000+ combo - - - - syslog: klogd startup succeeded
# <->1 2023-12-11T04:06:23.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-12-11T04:06:29.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.8
# <->1 2023-12-04T04:07:00.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-12-04T04:07:11.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\boot.log.9
# <->1 2023-11-27T04:06:06.000000+ combo - - - - cups: cupsd shutdown succeeded
# <->1 2023-11-27T04:06:17.000000+ combo - - - - cups: cupsd startup succeeded
# var\log\cron
# var\log\cron.1
# var\log\cron.10
# var\log\cron.11
# var\log\cron.12
# var\log\cron.13
# var\log\cron.14
# var\log\cron.15
# var\log\cron.16
# var\log\cron.17
# var\log\cron.18
# var\log\cron.19
# var\log\cron.2
# var\log\cron.20
# var\log\cron.21
# var\log\cron.22
# var\log\cron.23
# var\log\cron.24
# var\log\cron.25
# var\log\cron.26
# var\log\cron.27
# var\log\cron.28
# var\log\cron.29
# var\log\cron.3
# var\log\cron.30
# var\log\cron.31
# var\log\cron.32
# var\log\cron.33
# var\log\cron.4
# var\log\cron.5
# var\log\cron.6
# var\log\cron.7
# var\log\cron.8
# var\log\cron.9
# var\log\dmesg
# var\log\lastlog
# UnicodeDecodeError var\log\lastlog
# var\log\maillog
# var\log\maillog.1
# var\log\maillog.10
# var\log\maillog.11
# var\log\maillog.12
# var\log\maillog.13
# var\log\maillog.14
# var\log\maillog.15
# var\log\maillog.16
# var\log\maillog.17
# var\log\maillog.18
# var\log\maillog.19
# var\log\maillog.2
# var\log\maillog.20
# var\log\maillog.21
# var\log\maillog.22
# var\log\maillog.23
# var\log\maillog.24
# var\log\maillog.25
# var\log\maillog.26
# var\log\maillog.27
# var\log\maillog.28
# var\log\maillog.29
# var\log\maillog.3
# var\log\maillog.30
# var\log\maillog.31
# var\log\maillog.32
# var\log\maillog.33
# var\log\maillog.4
# var\log\maillog.5
# var\log\maillog.6
# var\log\maillog.7
# var\log\maillog.8
# var\log\maillog.9
# var\log\messages
# UnicodeDecodeError var\log\messages
# var\log\messages.1
# UnicodeDecodeError var\log\messages.1
# var\log\messages.10
# UnicodeDecodeError var\log\messages.10
# var\log\messages.11
# var\log\messages.12
# var\log\messages.13
# var\log\messages.14
# var\log\messages.15
# var\log\messages.16
# var\log\messages.17
# UnicodeDecodeError var\log\messages.17
# var\log\messages.18
# var\log\messages.19
# var\log\messages.2
# var\log\messages.20
# var\log\messages.21
# var\log\messages.22
# var\log\messages.23
# var\log\messages.24
# var\log\messages.25
# var\log\messages.26
# var\log\messages.27
# UnicodeDecodeError var\log\messages.27
# var\log\messages.28
# var\log\messages.29
# var\log\messages.3
# var\log\messages.30
# var\log\messages.31
# UnicodeDecodeError var\log\messages.31
# var\log\messages.32
# UnicodeDecodeError var\log\messages.32
# var\log\messages.33
# var\log\messages.4
# var\log\messages.5
# var\log\messages.6
# var\log\messages.7
# var\log\messages.8
# var\log\messages.9
# var\log\mysqld.log
# var\log\mysqld.log.1
# var\log\mysqld.log.10
# var\log\mysqld.log.11
# var\log\mysqld.log.12
# var\log\mysqld.log.13
# var\log\mysqld.log.14
# var\log\mysqld.log.15
# var\log\mysqld.log.16
# var\log\mysqld.log.17
# var\log\mysqld.log.18
# var\log\mysqld.log.19
# var\log\mysqld.log.2
# var\log\mysqld.log.20
# var\log\mysqld.log.21
# var\log\mysqld.log.22
# var\log\mysqld.log.23
# var\log\mysqld.log.24
# var\log\mysqld.log.25
# var\log\mysqld.log.26
# var\log\mysqld.log.27
# var\log\mysqld.log.28
# var\log\mysqld.log.29
# var\log\mysqld.log.3
# var\log\mysqld.log.30
# var\log\mysqld.log.31
# var\log\mysqld.log.32
# var\log\mysqld.log.33
# var\log\mysqld.log.4
# var\log\mysqld.log.5
# var\log\mysqld.log.6
# var\log\mysqld.log.7
# var\log\mysqld.log.8
# var\log\mysqld.log.9
# var\log\pacct
# UnicodeDecodeError var\log\pacct
# var\log\prelink.log
# var\log\rpmpkgs
# var\log\rpmpkgs.1
# var\log\rpmpkgs.10
# var\log\rpmpkgs.11
# var\log\rpmpkgs.12
# var\log\rpmpkgs.13
# ...
# var\log\httpd\agent_log.4
# var\log\httpd\agent_log.5
# var\log\httpd\agent_log.6
# var\log\httpd\agent_log.7
# var\log\httpd\agent_log.8
# var\log\httpd\agent_log.9
# var\log\httpd\audit_log
# UnicodeDecodeError var\log\httpd\audit_log
# var\log\httpd\audit_log.1
# UnicodeDecodeError var\log\httpd\audit_log.1
# var\log\httpd\audit_log.10
# UnicodeDecodeError var\log\httpd\audit_log.10
# var\log\httpd\audit_log.11
# UnicodeDecodeError var\log\httpd\audit_log.11
# var\log\httpd\audit_log.12
# var\log\httpd\audit_log.13
# var\log\httpd\audit_log.14
# UnicodeDecodeError var\log\httpd\audit_log.14
# var\log\httpd\audit_log.15
# UnicodeDecodeError var\log\httpd\audit_log.15
# var\log\httpd\audit_log.16
# var\log\httpd\audit_log.17
# UnicodeDecodeError var\log\httpd\audit_log.17
# var\log\httpd\audit_log.18
# UnicodeDecodeError var\log\httpd\audit_log.18
# var\log\httpd\audit_log.19
# UnicodeDecodeError var\log\httpd\audit_log.19
# var\log\httpd\audit_log.2
# UnicodeDecodeError var\log\httpd\audit_log.2
# var\log\httpd\audit_log.20
# UnicodeDecodeError var\log\httpd\audit_log.20
# var\log\httpd\audit_log.21
# UnicodeDecodeError var\log\httpd\audit_log.21
# var\log\httpd\audit_log.22
# UnicodeDecodeError var\log\httpd\audit_log.22
# var\log\httpd\audit_log.23
# UnicodeDecodeError var\log\httpd\audit_log.23
# var\log\httpd\audit_log.24
# var\log\httpd\audit_log.25
# UnicodeDecodeError var\log\httpd\audit_log.25
# var\log\httpd\audit_log.26
# UnicodeDecodeError var\log\httpd\audit_log.26
# var\log\httpd\audit_log.27
# UnicodeDecodeError var\log\httpd\audit_log.27
# var\log\httpd\audit_log.28
# var\log\httpd\audit_log.29
# UnicodeDecodeError var\log\httpd\audit_log.29
# var\log\httpd\audit_log.3
# var\log\httpd\audit_log.30
# UnicodeDecodeError var\log\httpd\audit_log.30
# var\log\httpd\audit_log.31
# var\log\httpd\audit_log.4
# UnicodeDecodeError var\log\httpd\audit_log.4
# var\log\httpd\audit_log.5
# var\log\httpd\audit_log.6
# UnicodeDecodeError var\log\httpd\audit_log.6
# var\log\httpd\audit_log.7
# UnicodeDecodeError var\log\httpd\audit_log.7
# var\log\httpd\audit_log.8
# UnicodeDecodeError var\log\httpd\audit_log.8
# var\log\httpd\audit_log.9
# UnicodeDecodeError var\log\httpd\audit_log.9
# var\log\httpd\error_log
# var\log\httpd\error_log.1
# var\log\httpd\error_log.10
# var\log\httpd\error_log.11
# var\log\httpd\error_log.12
# var\log\httpd\error_log.13
# var\log\httpd\error_log.14
# var\log\httpd\error_log.15
# var\log\httpd\error_log.16
# var\log\httpd\error_log.17
# var\log\httpd\error_log.18
# var\log\httpd\error_log.19
# var\log\httpd\error_log.2
# var\log\httpd\error_log.20
# var\log\httpd\error_log.21
# var\log\httpd\error_log.22
# var\log\httpd\error_log.23
# var\log\httpd\error_log.24
# var\log\httpd\error_log.25
# var\log\httpd\error_log.26
# var\log\httpd\error_log.27
# var\log\httpd\error_log.28
# var\log\httpd\error_log.29
# var\log\httpd\error_log.3
# var\log\httpd\error_log.30
# var\log\httpd\error_log.31
# var\log\httpd\error_log.32
# var\log\httpd\error_log.33
# var\log\httpd\error_log.4
# var\log\httpd\error_log.5
# var\log\httpd\error_log.6
# var\log\httpd\error_log.7
# var\log\httpd\error_log.8
# var\log\httpd\error_log.9
# var\log\httpd\jk2.shm
# var\log\httpd\modsec_debug_log
# var\log\httpd\referer_log
# var\log\httpd\referer_log.1
# var\log\httpd\referer_log.10
# var\log\httpd\referer_log.11
# var\log\httpd\referer_log.12
# var\log\httpd\referer_log.13
# var\log\httpd\referer_log.14
# var\log\httpd\referer_log.15
# var\log\httpd\referer_log.16
# var\log\httpd\referer_log.17
# var\log\httpd\referer_log.18
# var\log\httpd\referer_log.19
# var\log\httpd\referer_log.2
# var\log\httpd\referer_log.20
# var\log\httpd\referer_log.21
# var\log\httpd\referer_log.22
# var\log\httpd\referer_log.23
# var\log\httpd\referer_log.24
# var\log\httpd\referer_log.25
# var\log\httpd\referer_log.26
# var\log\httpd\referer_log.27
# var\log\httpd\referer_log.28
# var\log\httpd\referer_log.29
# var\log\httpd\referer_log.3
# var\log\httpd\referer_log.30
# var\log\httpd\referer_log.31
# var\log\httpd\referer_log.4
# var\log\httpd\referer_log.5
# var\log\httpd\referer_log.6
# var\log\httpd\referer_log.7
# var\log\httpd\referer_log.8
# var\log\httpd\referer_log.9
# var\log\httpd\ssl_access_log
# var\log\httpd\ssl_access_log.1
# var\log\httpd\ssl_access_log.2
# var\log\httpd\ssl_access_log.3
# var\log\httpd\ssl_access_log.4
# var\log\httpd\ssl_error_log
# var\log\httpd\ssl_error_log.1
# var\log\httpd\ssl_error_log.10
# var\log\httpd\ssl_error_log.11
# var\log\httpd\ssl_error_log.12
# var\log\httpd\ssl_error_log.13
# var\log\httpd\ssl_error_log.14
# var\log\httpd\ssl_error_log.15
# var\log\httpd\ssl_error_log.16
# var\log\httpd\ssl_error_log.17
# var\log\httpd\ssl_error_log.18
# var\log\httpd\ssl_error_log.19
# var\log\httpd\ssl_error_log.2
# var\log\httpd\ssl_error_log.20
# var\log\httpd\ssl_error_log.21
# var\log\httpd\ssl_error_log.22
# var\log\httpd\ssl_error_log.23
# var\log\httpd\ssl_error_log.24
# var\log\httpd\ssl_error_log.25
# var\log\httpd\ssl_error_log.26
# var\log\httpd\ssl_error_log.27
# var\log\httpd\ssl_error_log.28
# var\log\httpd\ssl_error_log.29
# var\log\httpd\ssl_error_log.3
# var\log\httpd\ssl_error_log.30
# var\log\httpd\ssl_error_log.31
# var\log\httpd\ssl_error_log.32
# var\log\httpd\ssl_error_log.33
# var\log\httpd\ssl_error_log.4
# var\log\httpd\ssl_error_log.5
# var\log\httpd\ssl_error_log.6
# var\log\httpd\ssl_error_log.7
# var\log\httpd\ssl_error_log.8
# var\log\httpd\ssl_error_log.9
# var\log\httpd\ssl_request_log
# var\log\httpd\ssl_request_log.1
# var\log\httpd\ssl_request_log.2
# var\log\httpd\ssl_request_log.3
# var\log\httpd\ssl_request_log.4
# var\log\iptraf\rvnamed.log
# var\log\mail\statistics
# UnicodeDecodeError var\log\mail\statistics
# var\log\mailman\error
# var\log\mailman\error.1
# var\log\mailman\error.10
# var\log\mailman\error.11
# var\log\mailman\error.12
# var\log\mailman\error.13
# var\log\mailman\error.14
# var\log\mailman\error.15
# var\log\mailman\error.16
# var\log\mailman\error.17
# var\log\mailman\error.18
# var\log\mailman\error.19
# var\log\mailman\error.2
# var\log\mailman\error.20
# var\log\mailman\error.21
# var\log\mailman\error.22
# var\log\mailman\error.23
# var\log\mailman\error.24
# var\log\mailman\error.25
# var\log\mailman\error.26
# var\log\mailman\error.27
# var\log\mailman\error.28
# var\log\mailman\error.29
# var\log\mailman\error.3
# var\log\mailman\error.30
# var\log\mailman\error.31
# var\log\mailman\error.32
# var\log\mailman\error.33
# var\log\mailman\error.4
# var\log\mailman\error.5
# var\log\mailman\error.6
# var\log\mailman\error.7
# var\log\mailman\error.8
# var\log\mailman\error.9
# var\log\mailman\fromusenet
# var\log\mailman\fromusenet.1
# var\log\mailman\fromusenet.10
# var\log\mailman\fromusenet.2
# var\log\mailman\fromusenet.3
# var\log\mailman\fromusenet.4
# var\log\mailman\fromusenet.5
# var\log\mailman\fromusenet.6
# var\log\mailman\fromusenet.7
# var\log\mailman\fromusenet.8
# var\log\mailman\fromusenet.9
# var\log\mailman\locks
# var\log\mailman\locks.1
# var\log\mailman\locks.10
# var\log\mailman\locks.2
# var\log\mailman\locks.3
# var\log\mailman\locks.4
# var\log\mailman\locks.5
# var\log\mailman\locks.6
# var\log\mailman\locks.7
# var\log\mailman\locks.8
# var\log\mailman\locks.9
# var\log\news\news.crit
# var\log\news\news.err
# var\log\news\news.notice
# var\log\privoxy\jarfile
# var\log\privoxy\logfile
# var\log\radius\radius.log
# var\log\radius\radius.log.1.gz
# UnicodeDecodeError var\log\radius\radius.log.1.gz
# var\log\radius\radius.log.2.gz
# UnicodeDecodeError var\log\radius\radius.log.2.gz
# var\log\radius\radius.log.3.gz
# UnicodeDecodeError var\log\radius\radius.log.3.gz
# var\log\radius\radius.log.4.gz
# UnicodeDecodeError var\log\radius\radius.log.4.gz
# var\log\radius\radutmp
# var\log\radius\radutmp.1.gz
# UnicodeDecodeError var\log\radius\radutmp.1.gz
# var\log\radius\radutmp.2.gz
# UnicodeDecodeError var\log\radius\radutmp.2.gz
# var\log\radius\radutmp.3.gz
# UnicodeDecodeError var\log\radius\radutmp.3.gz
# var\log\radius\radutmp.4.gz
# UnicodeDecodeError var\log\radius\radutmp.4.gz
# var\log\radius\radwtmp
# var\log\radius\radwtmp.1.gz
# UnicodeDecodeError var\log\radius\radwtmp.1.gz
# var\log\radius\radwtmp.2.gz
# UnicodeDecodeError var\log\radius\radwtmp.2.gz
# var\log\radius\radwtmp.3.gz
# UnicodeDecodeError var\log\radius\radwtmp.3.gz
# var\log\radius\radwtmp.4.gz
# UnicodeDecodeError var\log\radius\radwtmp.4.gz
# var\log\sa\sa18
# UnicodeDecodeError var\log\sa\sa18
# var\log\sa\sa19
# UnicodeDecodeError var\log\sa\sa19
# var\log\sa\sa20
# UnicodeDecodeError var\log\sa\sa20
# var\log\sa\sa21
# UnicodeDecodeError var\log\sa\sa21
# var\log\sa\sa22
# UnicodeDecodeError var\log\sa\sa22
# var\log\sa\sa23
# UnicodeDecodeError var\log\sa\sa23
# var\log\sa\sa24
# UnicodeDecodeError var\log\sa\sa24
# var\log\sa\sa25
# UnicodeDecodeError var\log\sa\sa25
# var\log\sa\sa26
# UnicodeDecodeError var\log\sa\sa26
# var\log\sa\sar17
# var\log\sa\sar18
# var\log\sa\sar19
# var\log\sa\sar20
# var\log\sa\sar21
# var\log\sa\sar22
# var\log\sa\sar23
# var\log\sa\sar24
# var\log\sa\sar25
# var\log\squid\access.log
# var\log\squid\access.log.1.gz
# UnicodeDecodeError var\log\squid\access.log.1.gz
# var\log\squid\access.log.10.gz
# UnicodeDecodeError var\log\squid\access.log.10.gz
# var\log\squid\access.log.11.gz
# UnicodeDecodeError var\log\squid\access.log.11.gz
# var\log\squid\access.log.12.gz
# UnicodeDecodeError var\log\squid\access.log.12.gz
# var\log\squid\access.log.13.gz
# UnicodeDecodeError var\log\squid\access.log.13.gz
# var\log\squid\access.log.14.gz
# UnicodeDecodeError var\log\squid\access.log.14.gz
# var\log\squid\access.log.15.gz
# UnicodeDecodeError var\log\squid\access.log.15.gz
# var\log\squid\access.log.16.gz
# UnicodeDecodeError var\log\squid\access.log.16.gz
# var\log\squid\access.log.17.gz
# UnicodeDecodeError var\log\squid\access.log.17.gz
# var\log\squid\access.log.18.gz
# UnicodeDecodeError var\log\squid\access.log.18.gz
# var\log\squid\access.log.19.gz
# UnicodeDecodeError var\log\squid\access.log.19.gz
# var\log\squid\access.log.2.gz
# UnicodeDecodeError var\log\squid\access.log.2.gz
# var\log\squid\access.log.20.gz
# UnicodeDecodeError var\log\squid\access.log.20.gz
# var\log\squid\access.log.21.gz
# UnicodeDecodeError var\log\squid\access.log.21.gz
# var\log\squid\access.log.22.gz
# UnicodeDecodeError var\log\squid\access.log.22.gz
# var\log\squid\access.log.23.gz
# UnicodeDecodeError var\log\squid\access.log.23.gz
# var\log\squid\access.log.24.gz
# UnicodeDecodeError var\log\squid\access.log.24.gz
# var\log\squid\access.log.25.gz
# UnicodeDecodeError var\log\squid\access.log.25.gz
# var\log\squid\access.log.26.gz
# UnicodeDecodeError var\log\squid\access.log.26.gz
# var\log\squid\access.log.27.gz
# UnicodeDecodeError var\log\squid\access.log.27.gz
# var\log\squid\access.log.28.gz
# UnicodeDecodeError var\log\squid\access.log.28.gz
# var\log\squid\access.log.29.gz
# UnicodeDecodeError var\log\squid\access.log.29.gz
# var\log\squid\access.log.3.gz
# UnicodeDecodeError var\log\squid\access.log.3.gz
# var\log\squid\access.log.30.gz
# UnicodeDecodeError var\log\squid\access.log.30.gz
# var\log\squid\access.log.31.gz
# UnicodeDecodeError var\log\squid\access.log.31.gz
# var\log\squid\access.log.4.gz
# UnicodeDecodeError var\log\squid\access.log.4.gz
# var\log\squid\access.log.5.gz
# UnicodeDecodeError var\log\squid\access.log.5.gz
# var\log\squid\access.log.6.gz
# UnicodeDecodeError var\log\squid\access.log.6.gz
# var\log\squid\access.log.7.gz
# UnicodeDecodeError var\log\squid\access.log.7.gz
# var\log\squid\access.log.8.gz
# UnicodeDecodeError var\log\squid\access.log.8.gz
# var\log\squid\access.log.9.gz
# UnicodeDecodeError var\log\squid\access.log.9.gz
# var\log\squid\cache.log
# var\log\squid\cache.log.1.gz
# UnicodeDecodeError var\log\squid\cache.log.1.gz
# var\log\squid\cache.log.10.gz
# UnicodeDecodeError var\log\squid\cache.log.10.gz
# var\log\squid\cache.log.11.gz
# UnicodeDecodeError var\log\squid\cache.log.11.gz
# var\log\squid\cache.log.12.gz
# UnicodeDecodeError var\log\squid\cache.log.12.gz
# var\log\squid\cache.log.13.gz
# UnicodeDecodeError var\log\squid\cache.log.13.gz
# var\log\squid\cache.log.14.gz
# UnicodeDecodeError var\log\squid\cache.log.14.gz
# var\log\squid\cache.log.15.gz
# UnicodeDecodeError var\log\squid\cache.log.15.gz
# var\log\squid\cache.log.16.gz
# UnicodeDecodeError var\log\squid\cache.log.16.gz
# var\log\squid\cache.log.17.gz
# UnicodeDecodeError var\log\squid\cache.log.17.gz
# var\log\squid\cache.log.18.gz
# UnicodeDecodeError var\log\squid\cache.log.18.gz
# var\log\squid\cache.log.19.gz
# UnicodeDecodeError var\log\squid\cache.log.19.gz
# var\log\squid\cache.log.2.gz
# UnicodeDecodeError var\log\squid\cache.log.2.gz
# var\log\squid\cache.log.20.gz
# UnicodeDecodeError var\log\squid\cache.log.20.gz
# var\log\squid\cache.log.21.gz
# UnicodeDecodeError var\log\squid\cache.log.21.gz
# var\log\squid\cache.log.22.gz
# UnicodeDecodeError var\log\squid\cache.log.22.gz
# var\log\squid\cache.log.23.gz
# UnicodeDecodeError var\log\squid\cache.log.23.gz
# var\log\squid\cache.log.24.gz
# UnicodeDecodeError var\log\squid\cache.log.24.gz
# var\log\squid\cache.log.25.gz
# UnicodeDecodeError var\log\squid\cache.log.25.gz
# var\log\squid\cache.log.26.gz
# UnicodeDecodeError var\log\squid\cache.log.26.gz
# var\log\squid\cache.log.27.gz
# UnicodeDecodeError var\log\squid\cache.log.27.gz
# var\log\squid\cache.log.28.gz
# UnicodeDecodeError var\log\squid\cache.log.28.gz
# var\log\squid\cache.log.29.gz
# UnicodeDecodeError var\log\squid\cache.log.29.gz
# var\log\squid\cache.log.3.gz
# UnicodeDecodeError var\log\squid\cache.log.3.gz
# var\log\squid\cache.log.30.gz
# UnicodeDecodeError var\log\squid\cache.log.30.gz
# var\log\squid\cache.log.31.gz
# UnicodeDecodeError var\log\squid\cache.log.31.gz
# var\log\squid\cache.log.4.gz
# UnicodeDecodeError var\log\squid\cache.log.4.gz
# var\log\squid\cache.log.5.gz
# UnicodeDecodeError var\log\squid\cache.log.5.gz
# var\log\squid\cache.log.6.gz
# UnicodeDecodeError var\log\squid\cache.log.6.gz
# var\log\squid\cache.log.7.gz
# UnicodeDecodeError var\log\squid\cache.log.7.gz
# var\log\squid\cache.log.8.gz
# UnicodeDecodeError var\log\squid\cache.log.8.gz
# var\log\squid\cache.log.9.gz
# UnicodeDecodeError var\log\squid\cache.log.9.gz
# var\log\squid\referer_log.log
# var\log\squid\squid.out
# var\log\squid\store.log
# var\log\squid\store.log.1.gz
# UnicodeDecodeError var\log\squid\store.log.1.gz
# var\log\squid\store.log.10.gz
# UnicodeDecodeError var\log\squid\store.log.10.gz
# var\log\squid\store.log.11.gz
# UnicodeDecodeError var\log\squid\store.log.11.gz
# var\log\squid\store.log.12.gz
# UnicodeDecodeError var\log\squid\store.log.12.gz
# var\log\squid\store.log.13.gz
# UnicodeDecodeError var\log\squid\store.log.13.gz
# var\log\squid\store.log.14.gz
# UnicodeDecodeError var\log\squid\store.log.14.gz
# var\log\squid\store.log.15.gz
# UnicodeDecodeError var\log\squid\store.log.15.gz
# var\log\squid\store.log.16.gz
# UnicodeDecodeError var\log\squid\store.log.16.gz
# var\log\squid\store.log.17.gz
# UnicodeDecodeError var\log\squid\store.log.17.gz
# var\log\squid\store.log.18.gz
# UnicodeDecodeError var\log\squid\store.log.18.gz
# var\log\squid\store.log.19.gz
# UnicodeDecodeError var\log\squid\store.log.19.gz
# var\log\squid\store.log.2.gz
# UnicodeDecodeError var\log\squid\store.log.2.gz
# var\log\squid\store.log.20.gz
# UnicodeDecodeError var\log\squid\store.log.20.gz
# var\log\squid\store.log.21.gz
# UnicodeDecodeError var\log\squid\store.log.21.gz
# var\log\squid\store.log.22.gz
# UnicodeDecodeError var\log\squid\store.log.22.gz
# var\log\squid\store.log.23.gz
# UnicodeDecodeError var\log\squid\store.log.23.gz
# var\log\squid\store.log.24.gz
# UnicodeDecodeError var\log\squid\store.log.24.gz
# var\log\squid\store.log.25.gz
# UnicodeDecodeError var\log\squid\store.log.25.gz
# var\log\squid\store.log.26.gz
# UnicodeDecodeError var\log\squid\store.log.26.gz
# var\log\squid\store.log.27.gz
# UnicodeDecodeError var\log\squid\store.log.27.gz
# var\log\squid\store.log.28.gz
# UnicodeDecodeError var\log\squid\store.log.28.gz
# var\log\squid\store.log.29.gz
# UnicodeDecodeError var\log\squid\store.log.29.gz
# var\log\squid\store.log.3.gz
# UnicodeDecodeError var\log\squid\store.log.3.gz
# var\log\squid\store.log.4.gz
# UnicodeDecodeError var\log\squid\store.log.4.gz
# var\log\squid\store.log.5.gz
# UnicodeDecodeError var\log\squid\store.log.5.gz
# var\log\squid\store.log.6.gz
# UnicodeDecodeError var\log\squid\store.log.6.gz
# var\log\squid\store.log.7.gz
# UnicodeDecodeError var\log\squid\store.log.7.gz
# var\log\squid\store.log.8.gz
# UnicodeDecodeError var\log\squid\store.log.8.gz
# var\log\squid\store.log.9.gz
# UnicodeDecodeError var\log\squid\store.log.9.gz
# var\log\squid\useragent_log.log
# var\log\uucp\Debug
# var\log\uucp\Log
# var\log\uucp\Stats
